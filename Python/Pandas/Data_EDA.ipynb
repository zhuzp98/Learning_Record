# %% [markdown]
# # EDA

# %%
import pandas as pd
import matplotlib as plt

# %%
# Read data .read_xxx
data = pd.read_excel("Project 2 - Marketing Research.xlsx")

# %%
# .head()
data.head()
# Out:
#    Search Frequency Rank          Search Term Top Clicked Brand #1  \
# 0                    813  patio furniture set                  FDW
# 1                   2647    outdoor furniture                  FDW
# 2                   2812    bedroom furniture                WLIVE
# 3                   4069      patio furniture                  FDW
# 4                   4252    furniture sliders              FLERISE
#
#   Top Clicked Brands #2 Top Clicked Brands #3 Top Clicked Category #1  \
# 0               Greesum                Devoko         Lawn and Garden
# 1               Allewie               Greesum         Lawn and Garden
# 2                CADUKE               Allewie               Furniture
# 3               Allewie                Devoko               Furniture
# 4           X-Protector                  CO-Z        Home Improvement
#
#   Top Clicked Category #2 Top Clicked Category #3  \
# 0               Furniture        Home Improvement
# ...

# %%
# .columns
data.columns
# Out:
# Index(['Search Frequency Rank', 'Search Term', 'Top Clicked Brand #1',
#        'Top Clicked Brands #2', 'Top Clicked Brands #3',
#        'Top Clicked Category #1', 'Top Clicked Category #2',
#        'Top Clicked Category #3', 'Top Clicked Product #1: ASIN',
#        'Top Clicked Product #1: Product Title',
#        'Top Clicked Product #1: Click Share',
#        'Top Clicked Product #1: Conversion Share',
#        'Top Clicked Product #2: ASIN', 'Top Clicked Product #2: Product Title',
#        'Top Clicked Product #2: Click Share',
#        'Top Clicked Product #2: Conversion Share',
#        'Top Clicked Product #3: ASIN', 'Top Clicked Product #3: Product Title',
#        'Top Clicked Product #3: Click Share',
#        'Top Clicked Product #3: Conversion Share', 'Reporting Date'],
#       dtype='object')

# %%
# .info()
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2777 entries, 0 to 2776
# Data columns (total 21 columns):
#  #   Column                                    Non-Null Count  Dtype
# ---  ------                                    --------------  -----
#  0   Search Frequency Rank                     2777 non-null   int64
#  1   Search Term                               2777 non-null   object
#  2   Top Clicked Brand #1                      2679 non-null   object
#  3   Top Clicked Brands #2                     2622 non-null   object
#  4   Top Clicked Brands #3                     2622 non-null   object
#  5   Top Clicked Category #1                   2777 non-null   object
#  6   Top Clicked Category #2                   2465 non-null   object
#  7   Top Clicked Category #3                   1728 non-null   object
#  8   Top Clicked Product #1: ASIN              2777 non-null   object
#  9   Top Clicked Product #1: Product Title     2777 non-null   object
# ...

# %%
# .describe()
data.describe()
# Out:
#        Search Frequency Rank  Top Clicked Product #1: Click Share  \
# count           2.777000e+03                          2777.000000
# mean            1.196895e+06                            16.643493
# min             8.130000e+02                             2.960000
# 25%             5.670740e+05                             9.070000
# 50%             1.174289e+06                            13.040000
# 75%             1.829371e+06                            20.000000
# max             2.444107e+06                           100.000000
# std             7.073248e+05                            12.310104
#
#        Top Clicked Product #1: Conversion Share  \
# count                               1982.000000
# mean                                  11.757195
# min                                    0.000000
# 25%                                    0.000000
# 50%                                    0.000000
# 75%                                   16.670000
# ...

# %%
# .drop()               drop columns
# data[['', '', '']]    select columns 
# .copy()               make a copy

# %%
#
